# %%
#importing pandas
import pandas as pd

# %%
information="""
Bussiness: -there is a client(ABC)
-Since 5 years they stopped producing the movies due to verious reasons.
-Now there are having 50 lakhs in there bank account. They want to produce for the best movie.
-Assume we are the data analysts, they came and asked us to analyze there historical data(Movies from there productions).
-Now our task is to suggest them what type of movies will give best profit. Based on there historical data.
"""

# %%
#They given there historical dataset
movies_data=pd.read_csv(r"D:\Temp\Data Science & Artificial Intelligence\Week-4\Class-21 On 14-02-2024 On Wednusday\Notes\14th\14th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")

# %%
movies_data
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies_data.shape
#it as total 559 movies with 6 columns
# Out:
# (559, 6)

# %%
type(movies_data)
# Out:
# pandas.core.frame.DataFrame

# %%
id(movies_data)
# Out:
# 1828962487328

# %%
len(movies_data)
# Out:
# 559

# %%
#columns
movies_data.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies_data.dtypes
# Out:
# Film                         object
# Genre                        object
# Rotten Tomatoes Ratings %     int64
# Audience Ratings %            int64
# Budget (million $)            int64
# Year of release               int64
# dtype: object

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies_data.isnull().sum()#there is no missing values or null vaules
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movies_data.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies_data.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies_data.columns=['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']
#changing column names

# %%
movies_data
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
#type casting the variables
movies_data.Film=movies_data.Film.astype('category')
movies_data.Genre=movies_data.Genre.astype('category')

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies_data.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies_data.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies_data.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies_data.CriticRating
# Out:
# 0      87
# 1       9
# 2      30
# 3      93
# 4      55
#        ..
# 554    26
# 555    68
# 556    89
# 557    90
# 558    14
# Name: CriticRating, Length: 559, dtype: int64

# %%
movies_data.AudienceRating
# Out:
# 0      81
# 1      44
# 2      52
# 3      84
# 4      70
#        ..
# 554    36
# 555    52
# 556    73
# 557    87
# 558    42
# Name: AudienceRating, Length: 559, dtype: int64

# %%
movies_data.BudgetMillions
# Out:
# 0        8
# 1      105
# 2       20
# 3       18
# 4       20
#       ...
# 554     50
# 555     18
# 556     65
# 557     24
# 558     80
# Name: BudgetMillions, Length: 559, dtype: int64

# %%
import numpy as np

# %%
movies_data.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: int64

# %%
movies_data.Film.cat.categories
#it is used to get the total values in an attribute.
#it is similar to the unique().
# Out:
# Index(['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours',
#        '17 Again ', '2012', '27 Dresses', '30 Days of Night',
#        '30 Minutes or Less', '50/50',
#        ...
#        'Yes Man', 'Yogi Bear', 'You Again', 'You Don't Mess with the Zohan',
#        'You Will Meet a Tall Dark Stranger', 'Your Highness',
#        'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper'],
#       dtype='object', length=559)

# %%
movies_data.Year.unique()
# Out:
# array([2009, 2008, 2010, 2007, 2011], dtype=int64)

# %%
from matplotlib import pyplot as plt
import warnings as w
w.filterwarnings('ignore')

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
movies_data.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize']=(7,5)
#Resizing the figure sizes

# %%
v=sns.jointplot(data=movies_data,x='CriticRating',y='AudienceRating')
"""
the jointplot() is used to create a plot that displays a relationship between two variables along with their individual distributions. It combines a scatter plot (or another kind of bivariate plot) with univariate histograms or density plots on the margins for both variables.

"""
plt.show()

# %%
v=sns.jointplot(data=movies_data,x='CriticRating',y='AudienceRating',hue='Genre')
plt.show()

# %%
j = sns.jointplot( data = movies_data, x = 'CriticRating', y = 'AudienceRating', kind='kde')
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
j = sns.jointplot( data = movies_data, x = 'CriticRating', y = 'AudienceRating', kind='reg')

j = sns.jointplot( data = movies_data, x = 'CriticRating', y = 'AudienceRating', kind='resid')

j = sns.jointplot( data = movies_data, x = 'CriticRating', y = 'AudienceRating', kind='hist')

j = sns.jointplot( data = movies_data, x = 'CriticRating', y = 'AudienceRating', kind='hex')

plt.show()

# %%
sns.set_style('darkgrid')#setting the background of a graph.

# %%
#Histograms

# <<< chat1

m1 = sns.distplot(movies_data.AudienceRating,bins=2)

#y - axis generated by seaborn automatically that is the powefull of seaborn gallery
plt.show()

# %%
m2=sns.distplot(movies_data['CriticRating'], bins=15)
plt.show()

# %%
sns.set_style('dark')

# %%
plt.hist(movies_data.AudienceRating,bins=15)
plt.show()

# %%
plt.hist(movies_data.AudienceRating,bins=20)
plt.show()

# %%
sns.set_style('white')

# %%
plt.hist(movies_data.CriticRating,bins=20)
plt.show()

# %%
plt.hist(movies_data.BudgetMillions,bins=15)
plt.show()

# %%
plt.hist(movies_data[movies_data['Genre']=='Drama'].BudgetMillions)
plt.show()

# %%
movies_data.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movies_data[movies_data.Genre == 'Action'].BudgetMillions, bins = 20,label='Action')
plt.hist(movies_data[movies_data.Genre == 'Thriller'].BudgetMillions, bins = 20,label='Thriller')
plt.hist(movies_data[movies_data.Genre == 'Drama'].BudgetMillions, bins = 20,label='Drama')
plt.legend()
plt.show()

# %%
sns.set_style('whitegrid')
plt.hist([movies_data[movies_data.Genre == 'Action'].BudgetMillions,\
          movies_data[movies_data.Genre == 'Drama'].BudgetMillions, \
          movies_data[movies_data.Genre == 'Thriller'].BudgetMillions, \
          movies_data[movies_data.Genre == 'Comedy'].BudgetMillions],stacked=True)
plt.legend()
plt.show()

# %%
sns.lmplot(data=movies_data,x='AudienceRating',y='BudgetMillions')
plt.show()

# %%
sns.lmplot(data=movies_data,x='AudienceRating',y='BudgetMillions',hue='Genre')
plt.show()

# %%
sns.set_style('white')
"""
Subplots: it means visualizing more than one graph in one plot is called subplots
"""
# Out:
# '\nSubplots: it means visualizing more than one graph in one plot is called subplots\n'

# %%
plt.subplots(1,3)#here we will get 1 row and 3 columns
plt.show()

# %%
plt.subplots(3,3,figsize=(10,8))#here we get 3 rows and 3 columns
plt.show()

# %%
movies_data
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
sns.boxplot(movies_data,x='Genre',y='CriticRating',hue='Genre')
plt.show()

# %%
"""
in the above graph 
=>comedy has highest criticrating and thriller has the highest average criticratings.
=>Horror has lowest criticrating and average criticratings.
"""
# Out:
# '\nin the above graph \n=>comedy has highest criticrating and thriller has the highest average criticratings.\n=>Horror has lowest criticrating and average criticratings.\n'

# %%
"""
violinplot(): these are the plots that similar to the boxplots, but different in the structure.
"""
# Out:
# '\nviolinplot(): these are the plots that similar to the boxplots, but different in the structure.\n'

# %%
sns.violinplot(data=movies_data,x='Genre',y='CriticRating',hue='Genre')
plt.show()

# %%
sns.violinplot(data=movies_data[(movies_data.Genre=='Thriller')|(movies_data.Genre=='Comedy')],x='Year', y='BudgetMillions',hue='Year')
plt.title('Thriler and Comedy',loc='left')
plt.show()

# %%
movies_data[(movies_data.Genre=='Thriller')|(movies_data.Genre=='Comedy')]
# Out:
#                                    Film     Genre  CriticRating  \
# 0                 (500) Days of Summer     Comedy            87
# 4                             17 Again     Comedy            55
# 6                            27 Dresses    Comedy            40
# 8                    30 Minutes or Less    Comedy            43
# 9                                 50/50    Comedy            93
# ..                                  ...       ...           ...
# 553  You Will Meet a Tall Dark Stranger    Comedy            43
# 554                       Your Highness    Comedy            26
# 555                     Youth in Revolt    Comedy            68
# 556                              Zodiac  Thriller            89
# 558                           Zookeeper    Comedy            14
#
#      AudienceRating  BudgetMillions  Year
# 0                81               8  2009
# 4                70              20  2009
# 6                71              30  2008
# ...

# %%
"""
=>till now we learned about univariate and bivariate analysis.
=>now it's time to visualize the graphs by using multiple variables.
=>We can visualize multiviarate analysis by using Facetgrid(), subplots(), heatmap() in seaborn
"""
# Out:
# "\n=>till now we learned about univariate and bivariate analysis.\n=>now it's time to visualize the graphs by using multiple variables.\n=>We can visualize multiviarate analysis by using Facetgrid(), subplots(), heatmap() in seaborn\n"

# %%
#FacetGrid() is used to plot the graphs based on multiple variables/attributes.
g=sns.FacetGrid(movies_data,row='Genre',col='Year',hue='Year')
#map() is used to appling the ploting function to every graph.
g=g.map(plt.scatter,'CriticRating','AudienceRating')
plt.show()

# %%
#with the help of the above graphs we can
"""
suggest the client for - 'Action movies'
did'nt suggest the client for 'Adventure movies'
suggest the client for 'Comedy movies'
suggest the client for 'Drama movies'
suggest the client for 'Horror movies'
did'nt suggest the client for 'Romance movies'
did'nt suggest the client for 'Thriller movies'
"""

#still we selected some genres but we need to suggest the one of them. now we can look for budget where the client is spending more.
# Out:
# "\nsuggest the client for - 'Action movies'\ndid'nt suggest the client for 'Adventure movies'\nsuggest the client for 'Comedy movies'\nsuggest the client for 'Drama movies'\nsuggest the client for 'Horror movies'\ndid'nt suggest the client for 'Romance movies'\ndid'nt suggest the client for 'Thriller movies'\n"

# %%
p=sns.FacetGrid(data=movies_data,row='Genre',col='Year',hue='Year')
p=p.map(plt.hist,'BudgetMillions')
plt.show()

# %%
plt.hist(movies_data[(movies_data.Genre=='Action')]['BudgetMillions'])
plt.show()

# %%
#we can suggest the client to spend on action or comedy movies.
