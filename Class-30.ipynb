# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading the dataset

# %%
data=pd.read_csv(r"D:\Temp\Data Science & Artificial Intelligence\Week-5\Class-30 On 26-02-2024 On Monday\Notes\23rd, 26th- course review, Stats Introduction\23rd, 26th- course review, Stats Introduction\PROJECT\Inc_Exp_Data.csv")
data
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %% [markdown]
# ## Analyze the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
data.shape
# Out:
# (50, 7)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
data.describe().transpose()
# Out:
#                        count       mean            std      min       25%  \
# Mthly_HH_Income         50.0   41558.00   26097.908979   5000.0   23550.0
# Mthly_HH_Expense        50.0   18818.00   12090.216824   2000.0   10000.0
# No_of_Fly_Members       50.0       4.06       1.517382      1.0       3.0
# Emi_or_Rent_Amt         50.0    3060.00    6241.434948      0.0       0.0
# Annual_HH_Income        50.0  490019.04  320135.792123  64200.0  258750.0
# No_of_Earning_Members   50.0       1.46       0.734291      1.0       1.0
#
#                             50%       75%        max
# Mthly_HH_Income         35000.0   50375.0   100000.0
# Mthly_HH_Expense        15500.0   25000.0    50000.0
# No_of_Fly_Members           4.0       5.0        7.0
# Emi_or_Rent_Amt             0.0    3500.0    35000.0
# Annual_HH_Income       447420.0  594720.0  1404000.0
# No_of_Earning_Members       1.0       2.0        4.0

# %%
data.isna().any()# no null values
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %%
data.Mthly_HH_Expense.mean() # mean of expense
# Out:
# 18818.0

# %%
data.Mthly_HH_Expense.median() # median of expense
# Out:
# 15500.0

# %%
mnt_exp_tmp=pd.crosstab(index=data.Mthly_HH_Expense,columns='Frequency').reset_index()
mnt_exp_tmp
# Out:
# col_0  Mthly_HH_Expense  Frequency
# 0                  2000          1
# 1                  4500          1
# 2                  5000          1
# 3                  6600          1
# 4                  7000          1
# 5                  8000          3
# 6                  9000          3
# 7                 10000          5
# 8                 10500          1
# 9                 12000          3
# 10                12300          1
# 11                13000          1
# 12                15000          3
# 13                16000          1
# 14                18000          1
# 15                19000          1
# 16                20000          6
# 17                22000          1
# 18                25000          8
# 19                30000          1
# 20                40000          2
# 21                45000          1
# 22                48000          1
# 23                50000          2

# %%
mnt_exp_tmp[mnt_exp_tmp.Frequency==data['Mthly_HH_Expense'].value_counts().max()] # high expense of most households
# Out:
# col_0  Mthly_HH_Expense  Frequency
# 18                25000          8

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.Highest_Qualified_Member.value_counts().plot(kind='bar') # highest education qualification is graduate.
plt.show()

# %%
data.plot(x='Mthly_HH_Income',y='Mthly_HH_Expense',marker='o') # monthly income and expense
# Out:
# <Axes: xlabel='Mthly_HH_Income'>

# %%
IQR=data['Mthly_HH_Expense'].quantile(0.75)-data['Mthly_HH_Expense'].quantile(0.25) # inter quartile range
IQR
# Out:
# 15000.0

# %%
data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
data.iloc[:,:4].std().to_frame().transpose() # first 4 columns standard deviation.
# .std() is used to get the standard deviations.
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt
# 0     26097.908979      12090.216824           1.517382      6241.434948

# %%
data.iloc[:,:3].var().to_frame().T # first 3 columns variance.
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members
# 0     6.811009e+08      1.461733e+08           2.302449

# %%
data.Highest_Qualified_Member.value_counts().to_frame().T # qualification counts
# Out:
# Highest_Qualified_Member  Graduate  Under-Graduate  Professional  \
# count                           19              10            10
#
# Highest_Qualified_Member  Post-Graduate  Illiterate
# count                                 6           5

# %%
data.No_of_Earning_Members.value_counts().plot(kind='bar')
plt.show()# in more families, 1 member is earning.
